# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#     Unnamed: 0  Rank                                 Name  Link Brand channel  \
# 0            0     1                             T-Series  Link           Yes
# 1            1     2                            Cocomelon  Link           Yes
# 2            2     3  Sony Entertainment Television India  Link           Yes
# 3            3     4                              MrBeast  Link            No
# 4            4     5                            PewDiePie  Link            No
# 5            5     6                      Kids Diana Show  Link           Yes
# 6            6     7                          Like Nastya  Link            No
# 7            7     8                        Vlad and Niki  Link            No
# 8            8     9                                  WWE  Link           Yes
# 9            9    10                    Zee Music Company  Link           Yes
# 10          10    11                            Blackpink  Link           Yes
# ...

# %% [markdown]
# ## hacemos el histograma de subscriptores

# %%
col_subs = df['Subscribers (millions)']
col_subs
# Out:
# 0     238.0
# 1     155.0
# 2     153.0
# 3     137.0
# 4     111.0
# 5     109.0
# 6     105.0
# 7      94.9
# 8      93.8
# 9      93.4
# 10     84.8
# 11     83.3
# 12     79.2
# 13     78.2
# 14     73.9
# 15     71.1
# 16     69.5
# 17     66.4
# 18     66.3
# 19     66.1
# 20     64.2
# 21     63.2
# 22     60.6
# 23     59.0
# 24     58.8
# 25     58.4
# 26     57.3
# 27     56.6
# 28     56.2
# 29     56.1
# 30     56.0
# 31     55.9
# 32     55.6
# 33     53.1
# 34     53.0
# 35     52.7
# 36     52.4
# 37     51.1
# 38     50.6
# 39     49.8
# 40     47.6
# 41     47.4
# 42     46.5
# 43     45.7
# 44     45.4
# 45     45.4
# 46     45.2
# 47     45.0
# 48     44.9
# 49     44.6
# Name: Subscribers (millions), dtype: float64
